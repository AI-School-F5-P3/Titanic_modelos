# %%
import pandas as pd
import xgboost as xgb
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (RandomForestClassifier, 
                              AdaBoostClassifier, BaggingClassifier,
                              ExtraTreesClassifier, GradientBoostingClassifier)
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import seaborn as sns
import matplotlib.pyplot as plt
import optuna

# %% [markdown]
# Cargamos el archivo y comprobamos que los datos efectivamente están limpios

# %%
df = pd.read_csv('Train_recoded.csv')
df.isnull().sum()
# Out:
# PassengerId     0
# HomePlanet      0
# CryoSleep       0
# Cabin           0
# Destination     0
# VIP             0
# Name            0
# Transported     0
# Algun_Gasto     0
# CabinDeck       0
# CabinSide       0
# Group           0
# GroupNumber     0
# Last Name       0
# Solo            0
# Age             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# Gastos          0
# CabinNumber     0
# GroupSize       0
# AgeGroup        0
# dtype: int64

# %% [markdown]
# Recoficamos las variables categóricas en numéricas asignandoles valores numéricos en orden (0, 1, 2...)

# %%
df.loc[:, 'HomePlanet'] = df['HomePlanet'].map({'Europa': 0, 'Earth': 1, 'Mars': 2}).astype(int)
df.loc[:, 'CabinDeck'] = df['CabinDeck'].map({'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'T': 7}).astype(int)
df.loc[:, 'CabinSide'] = df['CabinSide'].map({'P': 0, 'S': 1})
df.loc[:, 'CryoSleep'] = df['CryoSleep'].astype(int)
df.loc[:, 'Destination'] = df['Destination'].map({'TRAPPIST-1e': 0, 'PSO J318.5-22': 1, '55 Cancri e': 2}).astype(int)
# Out:
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_18692\2690992866.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0 0 0 ... 0 0 0]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'CryoSleep'] = df['CryoSleep'].astype(int)

# %% [markdown]
# Separamos los conjuntos de entrenamiento y test, se eliminan además aquellas columnas que no vayan a usarse para el entrenamiento.

# %%
columnas_no_usadas = ["PassengerId", "Name", "Last Name", "Cabin"]

df = df.drop(columns = columnas_no_usadas)

features_eliminadas = ['Solo']

y = df['Transported']
X = df.drop(['Transported'] + features_eliminadas, axis = 1).astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 42)

eval_set = [(X_train, y_train), (X_test, y_test)]

# %% [markdown]
# Hiperparametrización de los modelos de ensemble

# %%
space = {
    'n_estimators': hp.quniform('n_estimators', 100, 300, 1),
    'max_depth': hp.quniform('max_depth', 3, 10, 1),
    'gamma': hp.uniform('gamma', 0, 5),
    'reg_alpha': hp.quniform('reg_alpha', 0, 10, 1),
    'reg_lambda': hp.uniform('reg_lambda', 0, 10),
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
    'subsample': hp.uniform('subsample', 0.5, 1),  # Nuevo parámetro
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),  # Nuevo parámetro
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 10)  # Nuevo parámetro
}

def objective(space):
    clf = XGBClassifier(
                n_estimators=int(space['n_estimators']),
                max_depth=int(space['max_depth']),
                gamma=space['gamma'],
                reg_alpha=int(space['reg_alpha']),
                reg_lambda=space['reg_lambda'],
                min_child_weight=int(space['min_child_weight']),
                colsample_bytree=space['colsample_bytree'],
                subsample=space['subsample'],
                learning_rate=space['learning_rate'],
                scale_pos_weight=space['scale_pos_weight'],
                eval_metric='logloss'
            )
    
    evaluation = [(X_train, y_train), (X_test, y_test)]
    
    clf.fit(X_train, y_train,
            eval_set=evaluation,
            verbose=False)
    
    pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, pred > 0.5)
    
    return {'loss': -accuracy, 'status': STATUS_OK}

trials = Trials()

best_hyperparams = fmin(fn=objective,
                        space=space,
                        algo=tpe.suggest,
                        max_evals=100,  # Número de evaluaciones que deseas hacer
                        trials=trials)

best_params = {
    'n_estimators': int(best_hyperparams['n_estimators']),
    'max_depth': int(best_hyperparams['max_depth']),
    'gamma': best_hyperparams['gamma'],
    'reg_alpha': int(best_hyperparams['reg_alpha']),
    'reg_lambda': best_hyperparams['reg_lambda'],
    'min_child_weight': int(best_hyperparams['min_child_weight']),
    'colsample_bytree': best_hyperparams['colsample_bytree'],
    'subsample': best_hyperparams['subsample'],
    'learning_rate': best_hyperparams['learning_rate'],
    'scale_pos_weight': best_hyperparams['scale_pos_weight'],
    'eval_metric': 'logloss'
}

clf = XGBClassifier(**best_params)

def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'depth': trial.suggest_int('depth', 3, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-5, 100, log=True),
        'border_count': trial.suggest_int('border_count', 1, 255),
        'random_seed': 42,
        'verbose': 0
    }

    model = CatBoostClassifier(**params)
    model.fit(X_train, y_train, eval_set=(X_test, y_test), verbose=0)
    
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    
    return accuracy

# Ejecutar la optimización
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Obtener los mejores hiperparámetros
best_params = study.best_params
print('Mejores hiperparámetros:', best_params)

cat_best = CatBoostClassifier(**best_params)

# Define the parameter grid to search
param_grid = {
    'n_estimators': [300, 500,700,900,1100],
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 5, 7],
    'num_leaves': [20, 30, 40],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [0, 0.1, 0.5]
}

# Create the LGBMClassifier
lgbm = LGBMClassifier()

# Perform random search with cross-validation
random_search = RandomizedSearchCV(estimator=lgbm, param_distributions=param_grid, n_iter=10, cv=5)

# Fit the random search to the training data
random_search.fit(X_train, y_train)

# Get the best hyperparameters and the best score
best_params = random_search.best_params_
best_score = random_search.best_score_

# Create a new LGBMClassifier with the best hyperparameters
best_lgbm = LGBMClassifier(**best_params)

# Train the model using the best hyperparameters
best_lgbm.fit(X_train, y_train)
# Out:
# 100%|██████████| 100/100 [00:37<00:00,  2.66trial/s, best loss: -0.8013327780091628]
# [I 2024-09-25 04:58:59,913] A new study created in memory with name: no-name-04223b6b-d140-4f2f-9e5e-eef25b121cc5
# [I 2024-09-25 04:59:01,013] Trial 0 finished with value: 0.7488546438983756 and parameters: {'iterations': 390, 'learning_rate': 0.048883447727314226, 'depth': 4, 'l2_leaf_reg': 2.9376695686326375e-05, 'border_count': 1}. Best is trial 0 with value: 0.7488546438983756.
# [I 2024-09-25 04:59:03,192] Trial 1 finished with value: 0.8092461474385673 and parameters: {'iterations': 520, 'learning_rate': 0.048710327688348466, 'depth': 6, 'l2_leaf_reg': 23.267462282614357, 'border_count': 194}. Best is trial 1 with value: 0.8092461474385673.
# [I 2024-09-25 04:59:11,876] Trial 2 finished with value: 0.7975843398583924 and parameters: {'iterations': 508, 'learning_rate': 0.1530211617265362, 'depth': 10, 'l2_leaf_reg': 0.09205723128350364, 'border_count': 189}. Best is trial 1 with value: 0.8092461474385673.
# [I 2024-09-25 04:59:14,944] Trial 3 finished with value: 0.7996668054977093 and parameters: {'iterations': 774, 'learning_rate': 0.20965624894347554, 'depth': 7, 'l2_leaf_reg': 0.001853247704535058, 'border_count': 67}. Best is trial 1 with value: 0.8092461474385673.
# [I 2024-09-25 04:59:18,748] Trial 4 finished with value: 0.806747188671387 and parameters: {'iterations': 634, 'learning_rate': 0.2241819815152153, 'depth': 10, 'l2_leaf_reg': 48.24765727046911, 'border_count': 33}. Best is trial 1 with value: 0.8092461474385673.
# [I 2024-09-25 04:59:20,378] Trial 5 finished with value: 0.8046647230320699 and parameters: {'iterations': 548, 'learning_rate': 0.11209221012003655, 'depth': 4, 'l2_leaf_reg': 0.0008303772383338047, 'border_count': 143}. Best is trial 1 with value: 0.8092461474385673.
# [I 2024-09-25 04:59:21,445] Trial 6 finished with value: 0.8104956268221575 and parameters: {'iterations': 290, 'learning_rate': 0.11872257486835373, 'depth': 5, 'l2_leaf_reg': 0.24443199314017192, 'border_count': 153}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:23,353] Trial 7 finished with value: 0.7959183673469388 and parameters: {'iterations': 396, 'learning_rate': 0.2924554494315062, 'depth': 7, 'l2_leaf_reg': 0.00013918220425428827, 'border_count': 173}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:28,306] Trial 8 finished with value: 0.8063306955435235 and parameters: {'iterations': 609, 'learning_rate': 0.011703661968037564, 'depth': 9, 'l2_leaf_reg': 0.0004584888484998724, 'border_count': 149}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:31,126] Trial 9 finished with value: 0.8075801749271136 and parameters: {'iterations': 532, 'learning_rate': 0.10198732312786182, 'depth': 7, 'l2_leaf_reg': 0.5358105284970168, 'border_count': 226}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:31,410] Trial 10 finished with value: 0.8000832986255727 and parameters: {'iterations': 130, 'learning_rate': 0.1881004326404954, 'depth': 3, 'l2_leaf_reg': 1.2106200597667405, 'border_count': 97}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:31,999] Trial 11 finished with value: 0.8017492711370262 and parameters: {'iterations': 197, 'learning_rate': 0.07074078755131348, 'depth': 5, 'l2_leaf_reg': 31.370384897427925, 'border_count': 250}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:35,995] Trial 12 finished with value: 0.8100791336942941 and parameters: {'iterations': 927, 'learning_rate': 0.01093770819417142, 'depth': 6, 'l2_leaf_reg': 3.638338808289042, 'border_count': 208}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:39,772] Trial 13 finished with value: 0.8088296543107039 and parameters: {'iterations': 940, 'learning_rate': 0.012477504148430171, 'depth': 5, 'l2_leaf_reg': 0.01157292493975282, 'border_count': 111}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:46,227] Trial 14 finished with value: 0.8042482299042066 and parameters: {'iterations': 945, 'learning_rate': 0.14382100216624988, 'depth': 8, 'l2_leaf_reg': 1.3381762645586315, 'border_count': 208}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:49,406] Trial 15 finished with value: 0.7975843398583924 and parameters: {'iterations': 784, 'learning_rate': 0.25498368074009603, 'depth': 6, 'l2_leaf_reg': 0.04551995648400205, 'border_count': 163}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:50,490] Trial 16 finished with value: 0.807996668054977 and parameters: {'iterations': 277, 'learning_rate': 0.10366961201877234, 'depth': 5, 'l2_leaf_reg': 4.605194004115724, 'border_count': 247}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:52,571] Trial 17 finished with value: 0.8004997917534361 and parameters: {'iterations': 757, 'learning_rate': 0.17730124399638858, 'depth': 3, 'l2_leaf_reg': 0.12162343665450916, 'border_count': 118}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:54,294] Trial 18 finished with value: 0.8004997917534361 and parameters: {'iterations': 330, 'learning_rate': 0.07181393296167163, 'depth': 8, 'l2_leaf_reg': 0.011786641447730934, 'border_count': 81}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:54,570] Trial 19 finished with value: 0.8038317367763432 and parameters: {'iterations': 110, 'learning_rate': 0.12823647389785822, 'depth': 4, 'l2_leaf_reg': 5.464452890070422, 'border_count': 214}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 04:59:58,191] Trial 20 finished with value: 0.8075801749271136 and parameters: {'iterations': 877, 'learning_rate': 0.041793723869863825, 'depth': 6, 'l2_leaf_reg': 0.30988582349640337, 'border_count': 175}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 05:00:01,203] Trial 21 finished with value: 0.8009162848812995 and parameters: {'iterations': 654, 'learning_rate': 0.04381498689090244, 'depth': 6, 'l2_leaf_reg': 9.719034958607573, 'border_count': 195}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 05:00:02,972] Trial 22 finished with value: 0.807996668054977 and parameters: {'iterations': 460, 'learning_rate': 0.023442773965449193, 'depth': 5, 'l2_leaf_reg': 80.91927089028272, 'border_count': 139}. Best is trial 6 with value: 0.8104956268221575.
# [I 2024-09-25 05:00:04,120] Trial 23 finished with value: 0.8113286130778842 and parameters: {'iterations': 238, 'learning_rate': 0.08385508516036674, 'depth': 6, 'l2_leaf_reg': 16.052484044256808, 'border_count': 229}. Best is trial 23 with value: 0.8113286130778842.
# [I 2024-09-25 05:00:05,749] Trial 24 finished with value: 0.7980008329862557 and parameters: {'iterations': 217, 'learning_rate': 0.08329730100623388, 'depth': 8, 'l2_leaf_reg': 1.5248653253965618, 'border_count': 236}. Best is trial 23 with value: 0.8113286130778842.
# [I 2024-09-25 05:00:06,799] Trial 25 finished with value: 0.8125780924614744 and parameters: {'iterations': 270, 'learning_rate': 0.08684822356566303, 'depth': 5, 'l2_leaf_reg': 3.9651251268048098, 'border_count': 216}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:07,860] Trial 26 finished with value: 0.8038317367763432 and parameters: {'iterations': 274, 'learning_rate': 0.1280585980530675, 'depth': 4, 'l2_leaf_reg': 0.35859557495891475, 'border_count': 230}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:08,400] Trial 27 finished with value: 0.8046647230320699 and parameters: {'iterations': 187, 'learning_rate': 0.09409647640889279, 'depth': 5, 'l2_leaf_reg': 13.683533924948485, 'border_count': 252}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:09,590] Trial 28 finished with value: 0.7988338192419825 and parameters: {'iterations': 348, 'learning_rate': 0.12790147584872347, 'depth': 4, 'l2_leaf_reg': 0.011737384590501165, 'border_count': 157}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:11,065] Trial 29 finished with value: 0.8034152436484798 and parameters: {'iterations': 410, 'learning_rate': 0.0736775365894239, 'depth': 5, 'l2_leaf_reg': 3.841451638653083e-05, 'border_count': 26}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:12,081] Trial 30 finished with value: 0.8004997917534361 and parameters: {'iterations': 296, 'learning_rate': 0.1722283994668114, 'depth': 3, 'l2_leaf_reg': 3.1458681953962406, 'border_count': 180}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:13,224] Trial 31 finished with value: 0.8071636817992504 and parameters: {'iterations': 223, 'learning_rate': 0.05790540072086163, 'depth': 6, 'l2_leaf_reg': 2.499812630853787, 'border_count': 215}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:15,331] Trial 32 finished with value: 0.7988338192419825 and parameters: {'iterations': 443, 'learning_rate': 0.1142596346700065, 'depth': 6, 'l2_leaf_reg': 16.526541730747045, 'border_count': 202}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:16,141] Trial 33 finished with value: 0.8084131611828405 and parameters: {'iterations': 164, 'learning_rate': 0.031049870307471066, 'depth': 7, 'l2_leaf_reg': 0.7015074840888171, 'border_count': 225}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:17,827] Trial 34 finished with value: 0.8075801749271136 and parameters: {'iterations': 342, 'learning_rate': 0.06119335599078085, 'depth': 6, 'l2_leaf_reg': 0.13616020982111723, 'border_count': 197}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:18,773] Trial 35 finished with value: 0.8050812161599333 and parameters: {'iterations': 236, 'learning_rate': 0.1510494345042753, 'depth': 4, 'l2_leaf_reg': 8.21718959978562, 'border_count': 238}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:21,617] Trial 36 finished with value: 0.8034152436484798 and parameters: {'iterations': 699, 'learning_rate': 0.08769075677819796, 'depth': 5, 'l2_leaf_reg': 73.50836026776707, 'border_count': 192}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:24,082] Trial 37 finished with value: 0.8088296543107039 and parameters: {'iterations': 468, 'learning_rate': 0.051667270800855515, 'depth': 7, 'l2_leaf_reg': 28.460042039065968, 'border_count': 129}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:28,104] Trial 38 finished with value: 0.8088296543107039 and parameters: {'iterations': 853, 'learning_rate': 0.1182618175528035, 'depth': 6, 'l2_leaf_reg': 0.24970296814916124, 'border_count': 183}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:29,707] Trial 39 finished with value: 0.807996668054977 and parameters: {'iterations': 375, 'learning_rate': 0.031628374955147615, 'depth': 5, 'l2_leaf_reg': 0.04836466727494174, 'border_count': 216}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:30,420] Trial 40 finished with value: 0.8029987505206164 and parameters: {'iterations': 146, 'learning_rate': 0.20071662648830269, 'depth': 7, 'l2_leaf_reg': 0.8075167106338997, 'border_count': 157}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:32,879] Trial 41 finished with value: 0.8063306955435235 and parameters: {'iterations': 558, 'learning_rate': 0.08577943513685038, 'depth': 6, 'l2_leaf_reg': 21.20804551920906, 'border_count': 168}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:36,975] Trial 42 finished with value: 0.8109121199500208 and parameters: {'iterations': 590, 'learning_rate': 0.022441279661537375, 'depth': 7, 'l2_leaf_reg': 2.825033964602499, 'border_count': 222}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:42,161] Trial 43 finished with value: 0.8117451062057476 and parameters: {'iterations': 588, 'learning_rate': 0.013255485750322676, 'depth': 8, 'l2_leaf_reg': 2.626669138057378, 'border_count': 224}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:50,310] Trial 44 finished with value: 0.8100791336942941 and parameters: {'iterations': 626, 'learning_rate': 0.03214593954540098, 'depth': 9, 'l2_leaf_reg': 2.1692734565341096, 'border_count': 222}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:00:57,348] Trial 45 finished with value: 0.8104956268221575 and parameters: {'iterations': 498, 'learning_rate': 0.140859694453829, 'depth': 9, 'l2_leaf_reg': 6.380841388349815, 'border_count': 242}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:02,583] Trial 46 finished with value: 0.8092461474385673 and parameters: {'iterations': 582, 'learning_rate': 0.10194452063802631, 'depth': 8, 'l2_leaf_reg': 0.7162761919613644, 'border_count': 234}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:07,098] Trial 47 finished with value: 0.806747188671387 and parameters: {'iterations': 724, 'learning_rate': 0.06347759192714912, 'depth': 7, 'l2_leaf_reg': 45.22893200642762, 'border_count': 254}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:12,343] Trial 48 finished with value: 0.8084131611828405 and parameters: {'iterations': 656, 'learning_rate': 0.020648729417551956, 'depth': 8, 'l2_leaf_reg': 1.353105144581839, 'border_count': 204}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:14,766] Trial 49 finished with value: 0.807996668054977 and parameters: {'iterations': 518, 'learning_rate': 0.23046123265380536, 'depth': 7, 'l2_leaf_reg': 0.18814432950301305, 'border_count': 89}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:18,520] Trial 50 finished with value: 0.8071636817992504 and parameters: {'iterations': 598, 'learning_rate': 0.04819234320840883, 'depth': 9, 'l2_leaf_reg': 0.0019424944665999454, 'border_count': 63}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:24,162] Trial 51 finished with value: 0.8038317367763432 and parameters: {'iterations': 501, 'learning_rate': 0.1409314267339851, 'depth': 9, 'l2_leaf_reg': 6.540263021019362, 'border_count': 243}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:30,327] Trial 52 finished with value: 0.8059142024156601 and parameters: {'iterations': 310, 'learning_rate': 0.16484724713066817, 'depth': 10, 'l2_leaf_reg': 4.680969120403393, 'border_count': 223}. Best is trial 25 with value: 0.8125780924614744.
# [I 2024-09-25 05:01:35,734] Trial 53 finished with value: 0.8146605581007913 and parameters: {'iterations': 262, 'learning_rate': 0.13791549294044655, 'depth': 10, 'l2_leaf_reg': 10.93192466697037, 'border_count': 241}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:40,297] Trial 54 finished with value: 0.8038317367763432 and parameters: {'iterations': 260, 'learning_rate': 0.29412407455595235, 'depth': 10, 'l2_leaf_reg': 12.519178371044335, 'border_count': 186}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:48,212] Trial 55 finished with value: 0.8071636817992504 and parameters: {'iterations': 406, 'learning_rate': 0.10732904755078164, 'depth': 10, 'l2_leaf_reg': 35.07457701020504, 'border_count': 211}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:49,342] Trial 56 finished with value: 0.8054977092877967 and parameters: {'iterations': 253, 'learning_rate': 0.16012648890008865, 'depth': 5, 'l2_leaf_reg': 0.0643914240080866, 'border_count': 234}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:50,479] Trial 57 finished with value: 0.8050812161599333 and parameters: {'iterations': 186, 'learning_rate': 0.07601639363795608, 'depth': 8, 'l2_leaf_reg': 2.2985564344187455, 'border_count': 222}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:52,565] Trial 58 finished with value: 0.8021657642648896 and parameters: {'iterations': 365, 'learning_rate': 0.01022033152154067, 'depth': 7, 'l2_leaf_reg': 19.00173559726921, 'border_count': 246}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:53,673] Trial 59 finished with value: 0.802582257392753 and parameters: {'iterations': 301, 'learning_rate': 0.09429850798736687, 'depth': 5, 'l2_leaf_reg': 0.5630731451086246, 'border_count': 107}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:55,527] Trial 60 finished with value: 0.8021657642648896 and parameters: {'iterations': 559, 'learning_rate': 0.12025651799457875, 'depth': 4, 'l2_leaf_reg': 3.5529988816431795, 'border_count': 255}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:01:56,505] Trial 61 finished with value: 0.807996668054977 and parameters: {'iterations': 103, 'learning_rate': 0.14197035489419077, 'depth': 9, 'l2_leaf_reg': 6.728379875554649, 'border_count': 242}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:09,744] Trial 62 finished with value: 0.8013327780091628 and parameters: {'iterations': 668, 'learning_rate': 0.18730225321115626, 'depth': 10, 'l2_leaf_reg': 9.43865967672398, 'border_count': 232}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:14,379] Trial 63 finished with value: 0.8034152436484798 and parameters: {'iterations': 490, 'learning_rate': 0.12893760136702934, 'depth': 9, 'l2_leaf_reg': 1.2975220595402448, 'border_count': 200}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:17,524] Trial 64 finished with value: 0.8038317367763432 and parameters: {'iterations': 319, 'learning_rate': 0.1395706181524346, 'depth': 9, 'l2_leaf_reg': 88.72446298243807, 'border_count': 217}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:20,708] Trial 65 finished with value: 0.8017492711370262 and parameters: {'iterations': 432, 'learning_rate': 0.15014914899155804, 'depth': 8, 'l2_leaf_reg': 3.864869805117582, 'border_count': 244}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:24,794] Trial 66 finished with value: 0.8084131611828405 and parameters: {'iterations': 204, 'learning_rate': 0.039205608794788155, 'depth': 10, 'l2_leaf_reg': 0.023927705574912295, 'border_count': 226}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:26,714] Trial 67 finished with value: 0.8029987505206164 and parameters: {'iterations': 282, 'learning_rate': 0.09556856619907574, 'depth': 8, 'l2_leaf_reg': 0.34338769316946155, 'border_count': 209}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:27,221] Trial 68 finished with value: 0.7938359017076219 and parameters: {'iterations': 161, 'learning_rate': 0.021373449920809553, 'depth': 6, 'l2_leaf_reg': 11.750003057720017, 'border_count': 140}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:32,102] Trial 69 finished with value: 0.8059142024156601 and parameters: {'iterations': 241, 'learning_rate': 0.13491507286345872, 'depth': 10, 'l2_leaf_reg': 1.7973304871685105, 'border_count': 230}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:39,057] Trial 70 finished with value: 0.8088296543107039 and parameters: {'iterations': 539, 'learning_rate': 0.11168995074221147, 'depth': 9, 'l2_leaf_reg': 51.7948406851118, 'border_count': 239}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:42,621] Trial 71 finished with value: 0.8113286130778842 and parameters: {'iterations': 853, 'learning_rate': 0.010746559637165821, 'depth': 6, 'l2_leaf_reg': 6.125585961079797, 'border_count': 193}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:45,771] Trial 72 finished with value: 0.8125780924614744 and parameters: {'iterations': 870, 'learning_rate': 0.018096984431424865, 'depth': 5, 'l2_leaf_reg': 5.766073012524466, 'border_count': 176}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:48,851] Trial 73 finished with value: 0.8117451062057476 and parameters: {'iterations': 850, 'learning_rate': 0.016006611996525012, 'depth': 5, 'l2_leaf_reg': 2.8873194317299147, 'border_count': 178}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:52,176] Trial 74 finished with value: 0.8084131611828405 and parameters: {'iterations': 868, 'learning_rate': 0.017533313363355826, 'depth': 5, 'l2_leaf_reg': 22.53315706838333, 'border_count': 170}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:55,988] Trial 75 finished with value: 0.8100791336942941 and parameters: {'iterations': 915, 'learning_rate': 0.027651919514855287, 'depth': 6, 'l2_leaf_reg': 1.148243132661408e-05, 'border_count': 193}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:02:59,717] Trial 76 finished with value: 0.8050812161599333 and parameters: {'iterations': 982, 'learning_rate': 0.03828988383966708, 'depth': 5, 'l2_leaf_reg': 1.0167834343859654, 'border_count': 175}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:02,249] Trial 77 finished with value: 0.8009162848812995 and parameters: {'iterations': 784, 'learning_rate': 0.0536064048891056, 'depth': 4, 'l2_leaf_reg': 3.0653720864803753, 'border_count': 206}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:05,856] Trial 78 finished with value: 0.8100791336942941 and parameters: {'iterations': 904, 'learning_rate': 0.036033146550306566, 'depth': 6, 'l2_leaf_reg': 13.223580867274434, 'border_count': 149}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:08,814] Trial 79 finished with value: 0.8100791336942941 and parameters: {'iterations': 810, 'learning_rate': 0.01592239287194762, 'depth': 5, 'l2_leaf_reg': 5.829517882001593, 'border_count': 188}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:12,196] Trial 80 finished with value: 0.806747188671387 and parameters: {'iterations': 822, 'learning_rate': 0.045238470936930855, 'depth': 6, 'l2_leaf_reg': 41.39252147602031, 'border_count': 162}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:15,628] Trial 81 finished with value: 0.8034152436484798 and parameters: {'iterations': 980, 'learning_rate': 0.024927499687434507, 'depth': 5, 'l2_leaf_reg': 1.910067652215778, 'border_count': 150}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:19,105] Trial 82 finished with value: 0.8138275718450646 and parameters: {'iterations': 844, 'learning_rate': 0.012649199764957318, 'depth': 6, 'l2_leaf_reg': 9.190922953438536, 'border_count': 180}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:22,563] Trial 83 finished with value: 0.806747188671387 and parameters: {'iterations': 843, 'learning_rate': 0.011350321537059532, 'depth': 6, 'l2_leaf_reg': 9.211524587051372, 'border_count': 199}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:27,191] Trial 84 finished with value: 0.8038317367763432 and parameters: {'iterations': 953, 'learning_rate': 0.028934026805313047, 'depth': 7, 'l2_leaf_reg': 4.078097056930279, 'border_count': 185}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:31,866] Trial 85 finished with value: 0.8092461474385673 and parameters: {'iterations': 876, 'learning_rate': 0.019127562247181148, 'depth': 7, 'l2_leaf_reg': 19.215601281282748, 'border_count': 218}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:35,511] Trial 86 finished with value: 0.8088296543107039 and parameters: {'iterations': 900, 'learning_rate': 0.28224821756740587, 'depth': 6, 'l2_leaf_reg': 27.093245094620684, 'border_count': 178}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:38,202] Trial 87 finished with value: 0.8092461474385673 and parameters: {'iterations': 754, 'learning_rate': 0.06537208778875747, 'depth': 5, 'l2_leaf_reg': 8.47002135177225, 'border_count': 165}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:41,164] Trial 88 finished with value: 0.8000832986255727 and parameters: {'iterations': 807, 'learning_rate': 0.025620933913453603, 'depth': 6, 'l2_leaf_reg': 2.6961377937808266, 'border_count': 7}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:43,597] Trial 89 finished with value: 0.8050812161599333 and parameters: {'iterations': 758, 'learning_rate': 0.04526810345796496, 'depth': 4, 'l2_leaf_reg': 60.401541424785165, 'border_count': 208}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:46,196] Trial 90 finished with value: 0.806747188671387 and parameters: {'iterations': 710, 'learning_rate': 0.053368037359607434, 'depth': 5, 'l2_leaf_reg': 4.662629604790351, 'border_count': 195}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:49,084] Trial 91 finished with value: 0.8071636817992504 and parameters: {'iterations': 834, 'learning_rate': 0.07946971599609443, 'depth': 5, 'l2_leaf_reg': 0.9917502269027082, 'border_count': 131}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:52,260] Trial 92 finished with value: 0.8113286130778842 and parameters: {'iterations': 889, 'learning_rate': 0.035218128206457526, 'depth': 5, 'l2_leaf_reg': 1.7766555401901052, 'border_count': 173}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:56,116] Trial 93 finished with value: 0.8096626405664307 and parameters: {'iterations': 956, 'learning_rate': 0.035436651053157325, 'depth': 6, 'l2_leaf_reg': 14.462817114527315, 'border_count': 179}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:03:59,284] Trial 94 finished with value: 0.807996668054977 and parameters: {'iterations': 932, 'learning_rate': 0.014983687119316717, 'depth': 4, 'l2_leaf_reg': 5.984283256415481, 'border_count': 160}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:04:02,380] Trial 95 finished with value: 0.8054977092877967 and parameters: {'iterations': 861, 'learning_rate': 0.024639358972892017, 'depth': 5, 'l2_leaf_reg': 1.775902013350933, 'border_count': 170}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:04:06,366] Trial 96 finished with value: 0.8071636817992504 and parameters: {'iterations': 881, 'learning_rate': 0.011359321600274032, 'depth': 6, 'l2_leaf_reg': 0.47644802578173867, 'border_count': 213}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:04:10,925] Trial 97 finished with value: 0.8075801749271136 and parameters: {'iterations': 892, 'learning_rate': 0.03227337927495621, 'depth': 7, 'l2_leaf_reg': 2.801672010806367, 'border_count': 226}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:04:13,362] Trial 98 finished with value: 0.806747188671387 and parameters: {'iterations': 681, 'learning_rate': 0.017991296048692124, 'depth': 5, 'l2_leaf_reg': 0.000305957024532296, 'border_count': 182}. Best is trial 53 with value: 0.8146605581007913.
# [I 2024-09-25 05:04:17,317] Trial 99 finished with value: 0.8104956268221575 and parameters: {'iterations': 793, 'learning_rate': 0.06773214302756755, 'depth': 7, 'l2_leaf_reg': 7.844175760089494, 'border_count': 202}. Best is trial 53 with value: 0.8146605581007913.
# Mejores hiperparámetros: {'iterations': 262, 'learning_rate': 0.13791549294044655, 'depth': 10, 'l2_leaf_reg': 10.93192466697037, 'border_count': 241}
# [LightGBM] [Info] Number of positive: 2235, number of negative: 2245
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000470 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2157
# [LightGBM] [Info] Number of data points in the train set: 4480, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498884 -> initscore=-0.004464
# [LightGBM] [Info] Start training from score -0.004464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(learning_rate=0.01, max_depth=7, n_estimators=1100,
#                num_leaves=30, reg_alpha=0.5, reg_lambda=0.5)

# %% [markdown]
# Generamos el clasificador por votos

# %%
voting = VotingClassifier(estimators=[('lgbm',best_lgbm),('cat', cat_best), ('xg', clf)],voting='soft')
voting.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 2793, number of negative: 2807
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2160
# [LightGBM] [Info] Number of data points in the train set: 5600, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498750 -> initscore=-0.005000
# [LightGBM] [Info] Start training from score -0.005000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6228664	total: 25ms	remaining: 6.52s
# 1:	learn: 0.5700119	total: 51.7ms	remaining: 6.71s
# 2:	learn: 0.5301906	total: 77.5ms	remaining: 6.69s
# 3:	learn: 0.5021677	total: 99.1ms	remaining: 6.39s
# 4:	learn: 0.4767175	total: 121ms	remaining: 6.2s
# 5:	learn: 0.4632612	total: 142ms	remaining: 6.07s
# 6:	learn: 0.4512435	total: 161ms	remaining: 5.87s
# 7:	learn: 0.4413755	total: 181ms	remaining: 5.73s
# 8:	learn: 0.4307094	total: 200ms	remaining: 5.61s
# 9:	learn: 0.4228336	total: 219ms	remaining: 5.51s
# 10:	learn: 0.4137079	total: 238ms	remaining: 5.44s
# 11:	learn: 0.4084658	total: 258ms	remaining: 5.37s
# 12:	learn: 0.4025582	total: 277ms	remaining: 5.32s
# 13:	learn: 0.3977098	total: 298ms	remaining: 5.27s
# 14:	learn: 0.3902415	total: 317ms	remaining: 5.22s
# 15:	learn: 0.3876113	total: 335ms	remaining: 5.15s
# 16:	learn: 0.3819054	total: 354ms	remaining: 5.1s
# 17:	learn: 0.3783425	total: 374ms	remaining: 5.07s
# 18:	learn: 0.3744947	total: 394ms	remaining: 5.04s
# 19:	learn: 0.3720651	total: 414ms	remaining: 5.01s
# 20:	learn: 0.3701668	total: 434ms	remaining: 4.98s
# 21:	learn: 0.3670139	total: 455ms	remaining: 4.96s
# 22:	learn: 0.3645662	total: 478ms	remaining: 4.97s
# 23:	learn: 0.3624197	total: 504ms	remaining: 5s
# 24:	learn: 0.3603443	total: 526ms	remaining: 4.99s
# 25:	learn: 0.3567170	total: 548ms	remaining: 4.97s
# 26:	learn: 0.3554216	total: 572ms	remaining: 4.98s
# 27:	learn: 0.3534011	total: 600ms	remaining: 5.01s
# 28:	learn: 0.3501193	total: 628ms	remaining: 5.04s
# 29:	learn: 0.3482329	total: 650ms	remaining: 5.03s
# 30:	learn: 0.3460768	total: 674ms	remaining: 5.02s
# 31:	learn: 0.3444134	total: 696ms	remaining: 5s
# 32:	learn: 0.3417751	total: 719ms	remaining: 4.99s
# 33:	learn: 0.3387302	total: 741ms	remaining: 4.97s
# 34:	learn: 0.3349187	total: 762ms	remaining: 4.94s
# 35:	learn: 0.3321481	total: 783ms	remaining: 4.92s
# 36:	learn: 0.3302985	total: 804ms	remaining: 4.89s
# 37:	learn: 0.3285882	total: 825ms	remaining: 4.86s
# 38:	learn: 0.3258781	total: 846ms	remaining: 4.84s
# 39:	learn: 0.3242369	total: 865ms	remaining: 4.8s
# 40:	learn: 0.3219071	total: 887ms	remaining: 4.78s
# 41:	learn: 0.3193989	total: 907ms	remaining: 4.75s
# 42:	learn: 0.3169718	total: 929ms	remaining: 4.73s
# 43:	learn: 0.3156890	total: 949ms	remaining: 4.7s
# 44:	learn: 0.3149438	total: 960ms	remaining: 4.63s
# 45:	learn: 0.3134077	total: 981ms	remaining: 4.61s
# 46:	learn: 0.3124011	total: 1s	remaining: 4.6s
# 47:	learn: 0.3112190	total: 1.02s	remaining: 4.57s
# 48:	learn: 0.3094060	total: 1.05s	remaining: 4.55s
# 49:	learn: 0.3078241	total: 1.07s	remaining: 4.52s
# 50:	learn: 0.3061935	total: 1.09s	remaining: 4.5s
# 51:	learn: 0.3037878	total: 1.11s	remaining: 4.48s
# 52:	learn: 0.3027315	total: 1.13s	remaining: 4.46s
# 53:	learn: 0.3018827	total: 1.15s	remaining: 4.44s
# 54:	learn: 0.3005964	total: 1.17s	remaining: 4.42s
# 55:	learn: 0.2994009	total: 1.19s	remaining: 4.39s
# 56:	learn: 0.2979268	total: 1.22s	remaining: 4.37s
# 57:	learn: 0.2971284	total: 1.24s	remaining: 4.35s
# 58:	learn: 0.2950902	total: 1.26s	remaining: 4.32s
# 59:	learn: 0.2943284	total: 1.28s	remaining: 4.3s
# 60:	learn: 0.2934785	total: 1.3s	remaining: 4.28s
# 61:	learn: 0.2919053	total: 1.32s	remaining: 4.25s
# 62:	learn: 0.2901581	total: 1.34s	remaining: 4.23s
# 63:	learn: 0.2893427	total: 1.36s	remaining: 4.21s
# 64:	learn: 0.2870184	total: 1.38s	remaining: 4.19s
# 65:	learn: 0.2844953	total: 1.4s	remaining: 4.17s
# 66:	learn: 0.2836852	total: 1.42s	remaining: 4.14s
# 67:	learn: 0.2823367	total: 1.44s	remaining: 4.12s
# 68:	learn: 0.2816387	total: 1.46s	remaining: 4.09s
# 69:	learn: 0.2804514	total: 1.48s	remaining: 4.07s
# 70:	learn: 0.2794097	total: 1.5s	remaining: 4.05s
# 71:	learn: 0.2777943	total: 1.52s	remaining: 4.03s
# 72:	learn: 0.2754061	total: 1.55s	remaining: 4.01s
# 73:	learn: 0.2725890	total: 1.58s	remaining: 4s
# 74:	learn: 0.2716920	total: 1.6s	remaining: 3.99s
# 75:	learn: 0.2709405	total: 1.62s	remaining: 3.96s
# 76:	learn: 0.2700161	total: 1.64s	remaining: 3.94s
# 77:	learn: 0.2692844	total: 1.66s	remaining: 3.91s
# 78:	learn: 0.2684996	total: 1.68s	remaining: 3.89s
# 79:	learn: 0.2676369	total: 1.7s	remaining: 3.86s
# 80:	learn: 0.2663024	total: 1.72s	remaining: 3.84s
# 81:	learn: 0.2638818	total: 1.74s	remaining: 3.81s
# 82:	learn: 0.2630129	total: 1.75s	remaining: 3.79s
# 83:	learn: 0.2612695	total: 1.77s	remaining: 3.76s
# 84:	learn: 0.2606640	total: 1.79s	remaining: 3.73s
# 85:	learn: 0.2588676	total: 1.81s	remaining: 3.72s
# 86:	learn: 0.2565329	total: 1.83s	remaining: 3.69s
# 87:	learn: 0.2555529	total: 1.85s	remaining: 3.67s
# 88:	learn: 0.2542053	total: 1.87s	remaining: 3.64s
# 89:	learn: 0.2532891	total: 1.89s	remaining: 3.62s
# 90:	learn: 0.2524078	total: 1.91s	remaining: 3.6s
# 91:	learn: 0.2500133	total: 1.93s	remaining: 3.57s
# 92:	learn: 0.2489289	total: 1.95s	remaining: 3.55s
# 93:	learn: 0.2479184	total: 1.97s	remaining: 3.52s
# 94:	learn: 0.2471114	total: 1.99s	remaining: 3.5s
# 95:	learn: 0.2463278	total: 2.01s	remaining: 3.48s
# 96:	learn: 0.2457054	total: 2.03s	remaining: 3.46s
# 97:	learn: 0.2450086	total: 2.05s	remaining: 3.44s
# 98:	learn: 0.2436161	total: 2.07s	remaining: 3.41s
# 99:	learn: 0.2425041	total: 2.09s	remaining: 3.39s
# 100:	learn: 0.2417507	total: 2.11s	remaining: 3.36s
# 101:	learn: 0.2402450	total: 2.13s	remaining: 3.34s
# 102:	learn: 0.2384787	total: 2.15s	remaining: 3.32s
# 103:	learn: 0.2374259	total: 2.17s	remaining: 3.3s
# 104:	learn: 0.2360060	total: 2.19s	remaining: 3.28s
# 105:	learn: 0.2342287	total: 2.21s	remaining: 3.26s
# 106:	learn: 0.2334458	total: 2.24s	remaining: 3.24s
# 107:	learn: 0.2329518	total: 2.26s	remaining: 3.22s
# 108:	learn: 0.2322069	total: 2.28s	remaining: 3.2s
# 109:	learn: 0.2315816	total: 2.31s	remaining: 3.19s
# 110:	learn: 0.2309595	total: 2.33s	remaining: 3.17s
# 111:	learn: 0.2294726	total: 2.35s	remaining: 3.15s
# 112:	learn: 0.2286241	total: 2.37s	remaining: 3.13s
# 113:	learn: 0.2279854	total: 2.39s	remaining: 3.1s
# 114:	learn: 0.2264654	total: 2.41s	remaining: 3.08s
# 115:	learn: 0.2250847	total: 2.43s	remaining: 3.06s
# 116:	learn: 0.2239919	total: 2.45s	remaining: 3.04s
# 117:	learn: 0.2225175	total: 2.48s	remaining: 3.02s
# 118:	learn: 0.2215981	total: 2.5s	remaining: 3s
# 119:	learn: 0.2205245	total: 2.52s	remaining: 2.98s
# 120:	learn: 0.2197057	total: 2.54s	remaining: 2.96s
# 121:	learn: 0.2184257	total: 2.57s	remaining: 2.95s
# 122:	learn: 0.2178948	total: 2.59s	remaining: 2.93s
# 123:	learn: 0.2161776	total: 2.62s	remaining: 2.91s
# 124:	learn: 0.2156446	total: 2.64s	remaining: 2.89s
# 125:	learn: 0.2141793	total: 2.66s	remaining: 2.88s
# 126:	learn: 0.2126740	total: 2.69s	remaining: 2.85s
# 127:	learn: 0.2117352	total: 2.71s	remaining: 2.83s
# 128:	learn: 0.2111264	total: 2.73s	remaining: 2.82s
# 129:	learn: 0.2103490	total: 2.76s	remaining: 2.8s
# 130:	learn: 0.2095961	total: 2.78s	remaining: 2.78s
# 131:	learn: 0.2087311	total: 2.81s	remaining: 2.76s
# 132:	learn: 0.2080673	total: 2.84s	remaining: 2.75s
# 133:	learn: 0.2068896	total: 2.86s	remaining: 2.73s
# 134:	learn: 0.2053133	total: 2.89s	remaining: 2.71s
# 135:	learn: 0.2047295	total: 2.91s	remaining: 2.69s
# 136:	learn: 0.2041161	total: 2.92s	remaining: 2.67s
# 137:	learn: 0.2031164	total: 2.94s	remaining: 2.65s
# 138:	learn: 0.2020709	total: 2.97s	remaining: 2.63s
# 139:	learn: 0.2010365	total: 2.98s	remaining: 2.6s
# 140:	learn: 0.2005409	total: 3s	remaining: 2.58s
# 141:	learn: 0.1989800	total: 3.02s	remaining: 2.55s
# 142:	learn: 0.1979628	total: 3.04s	remaining: 2.53s
# 143:	learn: 0.1964056	total: 3.06s	remaining: 2.51s
# 144:	learn: 0.1952842	total: 3.08s	remaining: 2.49s
# 145:	learn: 0.1949344	total: 3.1s	remaining: 2.46s
# 146:	learn: 0.1941280	total: 3.12s	remaining: 2.44s
# 147:	learn: 0.1937588	total: 3.14s	remaining: 2.42s
# 148:	learn: 0.1932512	total: 3.16s	remaining: 2.4s
# 149:	learn: 0.1919741	total: 3.18s	remaining: 2.37s
# 150:	learn: 0.1911758	total: 3.2s	remaining: 2.35s
# 151:	learn: 0.1908402	total: 3.22s	remaining: 2.33s
# 152:	learn: 0.1903602	total: 3.24s	remaining: 2.31s
# 153:	learn: 0.1895023	total: 3.26s	remaining: 2.29s
# 154:	learn: 0.1891497	total: 3.28s	remaining: 2.26s
# 155:	learn: 0.1887483	total: 3.3s	remaining: 2.24s
# 156:	learn: 0.1881041	total: 3.32s	remaining: 2.22s
# 157:	learn: 0.1876911	total: 3.34s	remaining: 2.2s
# 158:	learn: 0.1867794	total: 3.36s	remaining: 2.17s
# 159:	learn: 0.1858155	total: 3.38s	remaining: 2.16s
# 160:	learn: 0.1853131	total: 3.4s	remaining: 2.13s
# 161:	learn: 0.1844517	total: 3.42s	remaining: 2.11s
# 162:	learn: 0.1841746	total: 3.44s	remaining: 2.09s
# 163:	learn: 0.1837899	total: 3.46s	remaining: 2.07s
# 164:	learn: 0.1833507	total: 3.48s	remaining: 2.05s
# 165:	learn: 0.1824681	total: 3.5s	remaining: 2.03s
# 166:	learn: 0.1816445	total: 3.53s	remaining: 2.01s
# 167:	learn: 0.1813017	total: 3.57s	remaining: 2s
# 168:	learn: 0.1809611	total: 3.59s	remaining: 1.98s
# 169:	learn: 0.1805538	total: 3.62s	remaining: 1.96s
# 170:	learn: 0.1796143	total: 3.65s	remaining: 1.94s
# 171:	learn: 0.1790964	total: 3.67s	remaining: 1.92s
# 172:	learn: 0.1784558	total: 3.69s	remaining: 1.9s
# 173:	learn: 0.1780172	total: 3.71s	remaining: 1.88s
# 174:	learn: 0.1772536	total: 3.73s	remaining: 1.86s
# 175:	learn: 0.1768330	total: 3.76s	remaining: 1.83s
# 176:	learn: 0.1764021	total: 3.78s	remaining: 1.81s
# 177:	learn: 0.1758405	total: 3.8s	remaining: 1.79s
# 178:	learn: 0.1756393	total: 3.82s	remaining: 1.77s
# 179:	learn: 0.1749115	total: 3.84s	remaining: 1.75s
# 180:	learn: 0.1744442	total: 3.86s	remaining: 1.73s
# 181:	learn: 0.1737737	total: 3.88s	remaining: 1.71s
# 182:	learn: 0.1734825	total: 3.9s	remaining: 1.68s
# 183:	learn: 0.1731973	total: 3.92s	remaining: 1.66s
# 184:	learn: 0.1727014	total: 3.94s	remaining: 1.64s
# 185:	learn: 0.1723615	total: 3.96s	remaining: 1.62s
# 186:	learn: 0.1711484	total: 3.99s	remaining: 1.6s
# 187:	learn: 0.1705957	total: 4.01s	remaining: 1.58s
# 188:	learn: 0.1697845	total: 4.03s	remaining: 1.55s
# 189:	learn: 0.1691743	total: 4.04s	remaining: 1.53s
# 190:	learn: 0.1684445	total: 4.07s	remaining: 1.51s
# 191:	learn: 0.1676556	total: 4.09s	remaining: 1.49s
# 192:	learn: 0.1667471	total: 4.11s	remaining: 1.47s
# 193:	learn: 0.1662219	total: 4.13s	remaining: 1.45s
# 194:	learn: 0.1659717	total: 4.15s	remaining: 1.43s
# 195:	learn: 0.1650081	total: 4.17s	remaining: 1.4s
# 196:	learn: 0.1643674	total: 4.19s	remaining: 1.38s
# 197:	learn: 0.1636930	total: 4.21s	remaining: 1.36s
# 198:	learn: 0.1630471	total: 4.23s	remaining: 1.34s
# 199:	learn: 0.1621926	total: 4.25s	remaining: 1.32s
# 200:	learn: 0.1615492	total: 4.27s	remaining: 1.3s
# 201:	learn: 0.1611241	total: 4.29s	remaining: 1.27s
# 202:	learn: 0.1609337	total: 4.31s	remaining: 1.25s
# 203:	learn: 0.1602979	total: 4.33s	remaining: 1.23s
# 204:	learn: 0.1597675	total: 4.35s	remaining: 1.21s
# 205:	learn: 0.1594195	total: 4.37s	remaining: 1.19s
# 206:	learn: 0.1589828	total: 4.39s	remaining: 1.17s
# 207:	learn: 0.1584800	total: 4.42s	remaining: 1.15s
# 208:	learn: 0.1578059	total: 4.44s	remaining: 1.13s
# 209:	learn: 0.1574360	total: 4.46s	remaining: 1.1s
# 210:	learn: 0.1566600	total: 4.48s	remaining: 1.08s
# 211:	learn: 0.1562507	total: 4.5s	remaining: 1.06s
# 212:	learn: 0.1557907	total: 4.52s	remaining: 1.04s
# 213:	learn: 0.1556226	total: 4.54s	remaining: 1.02s
# 214:	learn: 0.1548368	total: 4.56s	remaining: 998ms
# 215:	learn: 0.1543447	total: 4.58s	remaining: 977ms
# 216:	learn: 0.1540972	total: 4.61s	remaining: 955ms
# 217:	learn: 0.1534317	total: 4.63s	remaining: 934ms
# 218:	learn: 0.1532764	total: 4.65s	remaining: 913ms
# 219:	learn: 0.1530735	total: 4.67s	remaining: 892ms
# 220:	learn: 0.1525033	total: 4.69s	remaining: 870ms
# 221:	learn: 0.1521767	total: 4.71s	remaining: 849ms
# 222:	learn: 0.1517467	total: 4.73s	remaining: 828ms
# 223:	learn: 0.1514230	total: 4.75s	remaining: 806ms
# 224:	learn: 0.1511133	total: 4.77s	remaining: 785ms
# 225:	learn: 0.1505896	total: 4.79s	remaining: 764ms
# 226:	learn: 0.1502302	total: 4.81s	remaining: 742ms
# 227:	learn: 0.1499282	total: 4.83s	remaining: 721ms
# 228:	learn: 0.1494247	total: 4.85s	remaining: 700ms
# 229:	learn: 0.1484186	total: 4.88s	remaining: 678ms
# 230:	learn: 0.1479056	total: 4.9s	remaining: 657ms
# 231:	learn: 0.1475277	total: 4.92s	remaining: 636ms
# 232:	learn: 0.1472171	total: 4.94s	remaining: 615ms
# 233:	learn: 0.1467620	total: 4.96s	remaining: 594ms
# 234:	learn: 0.1463370	total: 4.98s	remaining: 573ms
# 235:	learn: 0.1458047	total: 5.01s	remaining: 552ms
# 236:	learn: 0.1454185	total: 5.03s	remaining: 531ms
# 237:	learn: 0.1450029	total: 5.05s	remaining: 509ms
# 238:	learn: 0.1447661	total: 5.07s	remaining: 488ms
# 239:	learn: 0.1445479	total: 5.1s	remaining: 467ms
# 240:	learn: 0.1440698	total: 5.12s	remaining: 446ms
# 241:	learn: 0.1434391	total: 5.14s	remaining: 425ms
# 242:	learn: 0.1432752	total: 5.16s	remaining: 403ms
# 243:	learn: 0.1427673	total: 5.18s	remaining: 382ms
# 244:	learn: 0.1425466	total: 5.2s	remaining: 361ms
# 245:	learn: 0.1423937	total: 5.22s	remaining: 340ms
# 246:	learn: 0.1421730	total: 5.25s	remaining: 319ms
# 247:	learn: 0.1414538	total: 5.26s	remaining: 297ms
# 248:	learn: 0.1409185	total: 5.28s	remaining: 276ms
# 249:	learn: 0.1405161	total: 5.31s	remaining: 255ms
# 250:	learn: 0.1399861	total: 5.33s	remaining: 233ms
# 251:	learn: 0.1393499	total: 5.34s	remaining: 212ms
# 252:	learn: 0.1387301	total: 5.37s	remaining: 191ms
# 253:	learn: 0.1383980	total: 5.39s	remaining: 170ms
# 254:	learn: 0.1381437	total: 5.41s	remaining: 148ms
# 255:	learn: 0.1376264	total: 5.43s	remaining: 127ms
# 256:	learn: 0.1373013	total: 5.45s	remaining: 106ms
# 257:	learn: 0.1368362	total: 5.47s	remaining: 84.8ms
# 258:	learn: 0.1364886	total: 5.49s	remaining: 63.5ms
# 259:	learn: 0.1362876	total: 5.51s	remaining: 42.4ms
# 260:	learn: 0.1357718	total: 5.53s	remaining: 21.2ms
# 261:	learn: 0.1356210	total: 5.55s	remaining: 0us
# VotingClassifier(estimators=[('lgbm',
#                               LGBMClassifier(learning_rate=0.01, max_depth=7,
#                                              n_estimators=1100, num_leaves=30,
#                                              reg_alpha=0.5, reg_lambda=0.5)),
#                              ('cat',
#                               <catboost.core.CatBoostClassifier object at 0x0000016929E42DB0>),
#                              ('xg',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8064703...
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.18969165012802183,
#                                             max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=10,
#                                             max_leaves=None,
#                                             min_child_weight=10, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=145, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...))],
#                  voting='soft')

# %%
scores = []
y_pred2 = voting.predict(X_test)
acc_final = accuracy_score(y_test,y_pred2)
scores.append(['Final soft voting with xg', acc_final])
print("Accuracy",acc_final)
# Out:
# Accuracy 0.8059142024156601

# %%
df_t = pd.read_csv('Test_recoded.csv')

df_test = df_t.drop(columns = ['Transported'] + columnas_no_usadas + features_eliminadas)

df_test.loc[:, 'HomePlanet'] = df_test['HomePlanet'].map({'Europa': 0, 'Earth': 1, 'Mars': 2}).astype(int)
df_test.loc[:, 'CabinDeck'] = df_test['CabinDeck'].map({'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'T': 7}).astype(int)
df_test.loc[:, 'CabinSide'] = df_test['CabinSide'].map({'P': 0, 'S': 1}).astype(int)
df_test.loc[:, 'CryoSleep'] = df_test['CryoSleep'].astype(int)
df_test.loc[:, 'Destination'] = df_test['Destination'].map({'TRAPPIST-1e': 0, 'PSO J318.5-22': 1, '55 Cancri e': 2}).astype(int)

df_test = df_test.astype(int)

prediccion = voting.predict(df_test)

df_predict = pd.DataFrame({
    'PassengerId': df_t['PassengerId'],
    'Transported': prediccion.astype(bool)
})

df_predict.to_csv('prediccion_stack_nosolo.csv', index = False)
# Out:
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_18692\1895226544.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1 0 1 ... 1 0 1]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df_test.loc[:, 'CryoSleep'] = df_test['CryoSleep'].astype(int)
